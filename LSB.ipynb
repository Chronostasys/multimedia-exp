# %% [markdown]
# # LSB

# %% [markdown]
# ## Imports

# %%
import io
import hide_info
import get_info
import matplotlib.pyplot as plt
from PIL import Image


f = io.open('flag.txt','w')
s = "U20181166"*10

# %% [markdown]
# ## Hide

# %%
f.write(s)
f.close()
hide_info.main()
f, arr = plt.subplots(1, 2)
arr[0].imshow(Image.open('old.png'), cmap='gray')
arr[0].set_title('origin')
arr[1].imshow(Image.open('new.png'), cmap='gray')
arr[1].set_title('LSB')
# Out:
# width:1024
# height:1024
# Text(0.5, 1.0, 'LSB')

# %% [markdown]
# ## Read

# %%
get_info.main()
f = io.open('get_flag.txt', 'r')
s = f.read()
f.close()
print('读取信息：' + s)
# Out:
# 完成信息提取！
# 读取信息：U20181166U20181166U20181166U20181166U20181166U20181166U20181166U20181166U20181166U20181166
